# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os, glob

path_PDF_He = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\AgA_He_PDF\\' #PDFusedinNMF.csv
path_IR_He = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\AgA_He_IR\\' #He_IRusedinNMF.csv
path_XRD_He = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\AgA_He_XRD\\' #XRDusedinNMF.csv

path_PDF_H2 = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\AgA_H2_PDF\\' #PDFusedinNMF.csv
path_IR_H2 = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\AgA_H2_IR\\' #H2_IRusedinNMF.csv
path_XRD_H2 = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\AgA_H2_XRD\\' #XRDusedinNMF.csv

r = [23.6,26.9,30.2,33.4,36.7,40,43.3,46.6,49.8,53.1,56.4,59.7,63,66.3,69.5,72.8,76.1,79.4,
     82.7,89.2,92.5,95.8,99.1,102.3,105.6,108.9,112.2,115.5,118.8,122,125.3,128.6,131.9,135.2,
     138.4,141.7,145,148.3,154.8,158.1,161.4,164.7,168,171.3,174.5,177.8,181.1,184.4,187.7,
     190.9,194.2,197.5,200.8,204.1,207.3,210.6,213.9,220.5,223.8,227,230.3,233.6,236.9,240.2,
     243.4,246.7,250,253.3,256.6,259.8,263.1,266.4,269.7,273,276.3,279.5,286.1,289.4,292.7,
     295.9,299.2,302.5,305.8,309.1,312.3,315.6,318.9] #temperatures

os.chdir(path_PDF_He)
PDF_He = pd.read_csv('PDFusedinNMF.csv',sep=',',index_col=0,header=0)
PDF_He.columns = r

os.chdir(path_IR_He)
IR_He = pd.read_csv('He_IRusedinNMF.csv',sep=',',index_col=0,header=0)
IR_He.columns = r

os.chdir(path_XRD_He)
XRD_He = pd.read_csv('XRDusedinNMF.csv',sep=',',index_col=0,header=0)
XRD_He.columns = r

os.chdir(path_PDF_H2)
PDF_H2 = pd.read_csv('PDFusedinNMF.csv',sep=',',index_col=0,header=0)
PDF_H2.columns = r

os.chdir(path_IR_H2)
IR_H2 = pd.read_csv('H2_IRusedinNMF.csv',sep=',',index_col=0,header=0)
IR_H2.columns = r

os.chdir(path_XRD_H2)
XRD_H2 = pd.read_csv('XRDusedinNMF.csv',sep=',',index_col=0,header=0)
XRD_H2.columns = r

output_path = r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\\'
os.chdir(output_path)

# %%
import matplotlib.gridspec as gridspec

f = plt.figure(dpi=600, edgecolor=None)
f.set_figheight(3.33*2.25)
f.set_figwidth(3.33*1.5)
gs0 = gridspec.GridSpec(1, 1, figure=f, hspace=0,wspace=0)
G00 = gridspec.GridSpecFromSubplotSpec(nrows=30, ncols=19, subplot_spec=gs0[0], hspace=0, wspace=0)
plt.rcParams.update({'font.size': 8})
ax = plt.subplot(G00[5:24,18])
ax.set_yticks([])

ax0 = plt.subplot(G00[0:9,0:9])
ax0 = sns.heatmap(XRD_H2_Pearson, square=True, cbar=True, cbar_ax=ax, vmin=0.40155078618261, vmax=1, yticklabels=10)
ax0.set_xticks([])
ax0.set_title(r'XRD $(H_{2})$',loc='left', pad=1)

ax1 = plt.subplot(G00[0:9,9:18])
ax1 = sns.heatmap(XRD_He_Pearson, square=True, cbar=False, vmin=0.8997557680494965, vmax=1)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title(r'XRD $(He)$',loc='left', pad=1)

ax2 = plt.subplot(G00[10:19,0:9])
ax2 = sns.heatmap(PDF_H2_Pearson, square=True, cbar=False, vmin=-0.09849087816182989, vmax=1, yticklabels=10)
ax2.set_xticks([])
ax2.set_ylabel(r'Temp. / $^\circ$C')
ax2.set_title(r'PDF $(H_{2})$',loc='left', pad=1)

ax3 = plt.subplot(G00[10:19,9:18])
ax3 = sns.heatmap(PDF_He_Pearson, square=True, cbar=False, vmin=0.46680174938839814, vmax=1)
ax3.set_xticks([])
ax3.set_yticks([])
ax3.set_title(r'PDF $(He)$',loc='left', pad=1)

ax4 = plt.subplot(G00[20:29,0:9])
ax4 = sns.heatmap(IR_H2_Pearson, square=True, cbar=False, vmin=0.3273799217224152, vmax=1, yticklabels=10, xticklabels=10)
ax4.set_xlabel(r'Temp. / $^\circ$C')
ax4.set_title(r'IR $(H_{2})$',loc='left', pad=1)

ax5 = plt.subplot(G00[20:29,9:18])
ax5 = sns.heatmap(IR_He_Pearson, square=True, cbar=False, vmin=0.6725901665308117, vmax=1, yticklabels=10, xticklabels=10)
ax5.set_xlabel(r'Temp. / $^\circ$C')
ax5.set_yticks([])
ax5.set_title(r'IR $(He)$',loc='left', pad=1)

cbar = ax0.collections[0].colorbar
cbar.set_ticks([0.40155078618261, 1])
cbar.set_ticklabels(['Low\nCorr.', 'High\nCorr.'])

plt.savefig('20210331_Dan_AgA_PearsonMaps.tif',bbox_inches='tight',dpi=2400)

# %%
import matplotlib.gridspec as gridspec

f = plt.figure(dpi=600, edgecolor=None)
f.set_figheight(3.33*1.5)
f.set_figwidth(3.33*2.25)
gs0 = gridspec.GridSpec(1, 1, figure=f, hspace=0,wspace=0)
G00 = gridspec.GridSpecFromSubplotSpec(nrows=19, ncols=28, subplot_spec=gs0[0], hspace=5, wspace=0.5)
plt.rcParams.update({'font.size': 8})
ax = plt.subplot(G00[:,27])
ax.set_yticks([])

ax0 = plt.subplot(G00[0:9,0:9])
ax0 = sns.heatmap(XRD_H2_Pearson, square=True, cbar=True, cbar_ax=ax, 
                  vmin=0.40155078618261, vmax=1, yticklabels=10, xticklabels=10)
ax0.set_xticks([])
ax0.set_title(r'XRD $(H_{2})$',loc='left', pad=1)
ax0.set_ylabel(r'Temp. / $^\circ$C')

ax1 = plt.subplot(G00[9:18,0:9])
ax1 = sns.heatmap(XRD_He_Pearson, square=True, cbar=False, 
                  vmin=0.8997557680494965, vmax=1, yticklabels=10, xticklabels=10)
ax1.set_title(r'XRD $(He)$',loc='left', pad=1)
ax1.set_ylabel(r'Temp. / $^\circ$C')

ax2 = plt.subplot(G00[0:9,9:18])
ax2 = sns.heatmap(PDF_H2_Pearson, square=True, cbar=False, 
                  vmin=-0.09849087816182989, vmax=1, yticklabels=10, xticklabels=10)
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_title(r'PDF $(H_{2})$',loc='left', pad=1)

ax3 = plt.subplot(G00[9:18,9:18])
ax3 = sns.heatmap(PDF_He_Pearson, square=True, cbar=False, 
                  vmin=0.46680174938839814, vmax=1, yticklabels=10, xticklabels=10)
ax3.set_yticks([])
ax3.set_title(r'PDF $(He)$',loc='left', pad=1)
ax3.set_xlabel(r'Temp. / $^\circ$C')

ax4 = plt.subplot(G00[0:9,18:27])
ax4 = sns.heatmap(IR_H2_Pearson, square=True, cbar=False, 
                  vmin=0.3273799217224152, vmax=1, yticklabels=10, xticklabels=10)
ax4.set_xticks([])
ax4.set_yticks([])
ax4.set_title(r'IR $(H_{2})$',loc='left', pad=1)

ax5 = plt.subplot(G00[9:18,18:27])
ax5 = sns.heatmap(IR_He_Pearson, square=True, cbar=False, 
                  vmin=0.6725901665308117, vmax=1, yticklabels=10, xticklabels=10)
ax5.set_yticks([])
ax5.set_title(r'IR $(He)$',loc='left', pad=1)

cbar = ax0.collections[0].colorbar
cbar.set_ticks([0.40155078618261, 1])
cbar.set_ticklabels(['Low\nCorr.', 'High\nCorr.'])

plt.savefig('20210331_Dan_AgA_PearsonMaps_alt.tif',bbox_inches='tight',dpi=2400)

# %%
pearson_output = pd.concat([XRD_H2_Pearson.iloc[:,-1],XRD_He_Pearson.iloc[:,-1],
                            PDF_H2_Pearson.iloc[:,-1],PDF_He_Pearson.iloc[:,-1], 
                            IR_H2_Pearson.iloc[:,-1],IR_He_Pearson.iloc[:,-1]],join='outer', axis=1)
pearson_output.to_csv('pearson_output-1.csv',sep=',')

# %%
import matplotlib.gridspec as gridspec
import pandas as pd

pc = pd.read_csv('DifferentialPearson.csv',sep=',',index_col=0,header=1,skiprows=[2])
pc.head()
# Out:
#         XRD_H2    XRD_He    PDF_H2    PDF_He     IR_H2     IR_He  XRD_H2.1  \
# 26.9 -0.000004 -0.000002 -0.004727 -0.003151 -0.000039 -0.000046  0.000327
# 30.2 -0.000005 -0.000003 -0.000516 -0.000024 -0.000095 -0.000015  0.000288
# 33.4 -0.000013 -0.000007  0.000780  0.000056 -0.000038 -0.000032  0.000057
# 36.7 -0.000024 -0.000013 -0.000777 -0.000141 -0.000316 -0.000121  0.000464
# 40.0 -0.000028 -0.000018 -0.000219  0.000186 -0.000252 -0.000205  0.000166
#
#       XRD_He.1  PDF_H2.1  PDF_He.1   IR_H2.1   IR_He.1
# 26.9  0.000194  0.000250  0.001219  0.000691  0.000639
# 30.2  0.000165  0.000073  0.001920  0.002077  0.000512
# 33.4  0.000262  0.001758  0.000982  0.001851  0.001904
# 36.7  0.000319  0.001771  0.001161  0.001489  0.002015
# 40.0  0.000294  0.000411  0.001597  0.002424  0.001673

# %%
f = plt.figure(dpi=600, edgecolor=None)
f.set_figheight(3.33*2)
f.set_figwidth(3.33*3)
gs0 = gridspec.GridSpec(1, 1, figure=f, hspace=0,wspace=0)
G00 = gridspec.GridSpecFromSubplotSpec(nrows=2, ncols=3, subplot_spec=gs0[0], hspace=0.2, wspace=0.2)
plt.rcParams.update({'font.size': 8})

ax0 = plt.subplot(G00[0,0])
ax0.set_ylabel(r'$\Delta$(Pearson Corr.)')
ax0.set_title(r'XRD $(H_{2})$',loc='left', pad=4)
ax0.plot(pc['XRD_H2'])
ax0.plot(pc['XRD_H2.1'])

ax1 = plt.subplot(G00[0,1])
ax1.set_title(r'PDF $(H_{2})$',loc='left', pad=4)
ax1.plot(pc['PDF_H2'])
ax1.plot(pc['PDF_H2.1'])

ax2 = plt.subplot(G00[0,2])
ax2.set_title(r'IR $(H_{2})$',loc='left', pad=4)
ax2.plot(pc['IR_H2'])
ax2.plot(pc['IR_H2.1'])

ax3 = plt.subplot(G00[1,0])
ax3.set_ylabel(r'$\Delta$(Pearson Corr.)')
ax3.set_title(r'XRD $(He)$',loc='left', pad=4)
ax3.plot(pc['XRD_He'])
ax3.plot(pc['XRD_He.1'])

ax4 = plt.subplot(G00[1,1])
ax4.set_xlabel(r'Temp. / $^\circ$C')
ax4.set_title(r'PDF $(He)$',loc='left', pad=4)
ax4.plot(pc['PDF_He'])
ax4.plot(pc['PDF_He.1'])

ax5 = plt.subplot(G00[1,2])
ax5.set_title(r'IR $(He)$',loc='left', pad=4)
ax5.plot(pc['IR_He'])
ax5.plot(pc['IR_He.1'])

x_axis = (np.array(pc.index))
ax0.fill_between(x_axis[7:21],pc.iloc[7:21,0],pc.iloc[7:21,6],
                 facecolor='green', alpha=0.2, interpolate=True)
ax1.fill_between(x_axis[7:21],pc.iloc[7:21,2],pc.iloc[7:21,8],
                 facecolor='green', alpha=0.2, interpolate=True)
ax2.fill_between(x_axis[7:21],pc.iloc[7:21,4],pc.iloc[7:21,10],
                 facecolor='green', alpha=0.2, interpolate=True)
ax3.fill_between(x_axis[7:21],pc.iloc[7:21,1],pc.iloc[7:21,7],
                 facecolor='green', alpha=0.2, interpolate=True)
ax4.fill_between(x_axis[7:21],pc.iloc[7:21,3],pc.iloc[7:21,9],
                 facecolor='green', alpha=0.2, interpolate=True)
ax5.fill_between(x_axis[7:21],pc.iloc[7:21,5],pc.iloc[7:21,11],
                 facecolor='green', alpha=0.2, interpolate=True)
ax0.fill_between(x_axis[34:44],pc.iloc[34:44,0],pc.iloc[34:44,6],
                 facecolor='red', alpha=0.2, interpolate=True)
ax1.fill_between(x_axis[34:44],pc.iloc[34:44,2],pc.iloc[34:44,8],
                 facecolor='red', alpha=0.2, interpolate=True)
ax2.fill_between(x_axis[34:44],pc.iloc[34:44,4],pc.iloc[34:44,10],
                 facecolor='red', alpha=0.2, interpolate=True)
ax3.fill_between(x_axis[72:],pc.iloc[72:,1],pc.iloc[72:,7],
                 facecolor='red', alpha=0.2, interpolate=True)
ax4.fill_between(x_axis[72:],pc.iloc[72:,3],pc.iloc[72:,9],
                 facecolor='red', alpha=0.2, interpolate=True)
ax5.fill_between(x_axis[72:],pc.iloc[72:,5],pc.iloc[72:,11],
                 facecolor='red', alpha=0.2, interpolate=True)
import matplotlib.patches as mpatches
colors = ["#cce5cc", "#ffcccc", "#1f76b4", "#ff7f0e"]
texts = ["Transition I", "Transition II", "Start Corr.", "End Corr."]
patches = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors[i], 
            label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
ax0.legend(handles=patches,loc=1, ncol=1, facecolor=None, frameon=False,fontsize=6)
ax1.legend(handles=patches,loc=1, ncol=1, facecolor=None, frameon=False,fontsize=6)
ax2.legend(handles=patches,loc=1, ncol=1, facecolor=None, frameon=False,fontsize=6)
ax3.legend(handles=patches,loc=4, ncol=1, facecolor=None, frameon=False,fontsize=6)
ax4.legend(handles=patches,loc=4, ncol=1, facecolor=None, frameon=False,fontsize=6)
ax5.legend(handles=patches,loc=4, ncol=1, facecolor=None, frameon=False,fontsize=6)

plt.savefig('20210401_Dan_AgA_DifferentialPearsonPlots_alt.tif',bbox_inches='tight',dpi=600)

# %%
xxx = (np.array(pc.index))
print(xxx[72:])
# Out:
# [273.  276.3 279.5 286.1 289.4 292.7 295.9 299.2 302.5 305.8 309.1 312.3
#  315.6 318.9]

# %%
print(pc.iloc[8:18,:])
# Out:
#         XRD_H2    XRD_He    PDF_H2    PDF_He     IR_H2     IR_He  XRD_H2.1  \
# 53.1 -0.000146 -0.000118 -0.000304 -0.000538 -0.002901 -0.002521  0.000738
# 56.4 -0.000171 -0.000228 -0.001664 -0.000981 -0.002465 -0.001838  0.000898
# 59.7 -0.000245 -0.000297 -0.000969 -0.002346 -0.003228 -0.002602  0.001003
# 63.0 -0.000358 -0.000423 -0.002435 -0.001700 -0.003420 -0.002863  0.001163
# 66.3 -0.000506 -0.000675 -0.003224 -0.003788 -0.004495 -0.003182  0.001233
# 69.5 -0.000851 -0.000964 -0.005586 -0.003610 -0.004165 -0.004478  0.001791
# 72.8 -0.001057 -0.001374 -0.008466 -0.006725 -0.005186 -0.004952  0.001675
# 76.1 -0.001766 -0.001875 -0.009799 -0.007430 -0.006491 -0.004915  0.001723
# 79.4 -0.002244 -0.002650 -0.012172 -0.010702 -0.006232 -0.004956  0.001275
# 82.7 -0.003108 -0.008195 -0.033496 -0.029682 -0.011900 -0.013058  0.001328
#
#       XRD_He.1  PDF_H2.1  PDF_He.1   IR_H2.1   IR_He.1
# 53.1  0.000654  0.004416  0.003517  0.008348  0.009055
# ...

# %%
import matplotlib.gridspec as gridspec
import pandas as pd

pc = pd.read_csv('DifferentialPearson.csv',sep=',',index_col=0,header=1,skiprows=[2])

f = plt.figure(dpi=600, edgecolor=None)
f.set_figheight(3.33*1)
f.set_figwidth(3.33*2)
gs0 = gridspec.GridSpec(1, 1, figure=f, hspace=0,wspace=0)
G00 = gridspec.GridSpecFromSubplotSpec(nrows=1, ncols=2, subplot_spec=gs0[0], hspace=0.2, wspace=0.2)
plt.rcParams.update({'font.size': 8})

ax0 = plt.subplot(G00[0,0])
ax0.set_ylabel(r'$\Delta$(Pearson Corr.)')
ax0.set_xlabel(r'Temp. / $^\circ$C')

ax0.plot(pc['XRD_H2'],color='#4c34eb')
ax0.plot(pc['XRD_H2.1'],color='#ed2f2f')
ax0.plot(pc['PDF_H2'],color='#6f5ced')
ax0.plot(pc['PDF_H2.1'],color='#e85a5a')
ax0.plot(pc['IR_H2'],color='#9587ed')
ax0.plot(pc['IR_H2.1'],color='#e08080')

ax3 = plt.subplot(G00[0,1])
ax3.set_xlabel(r'Temp. / $^\circ$C')
ax3.set_ylim(-0.032,0.023)

ax3.plot(pc['XRD_He'],color='#4c34eb')
ax3.plot(pc['XRD_He.1'],color='#ed2f2f')
ax3.plot(pc['PDF_He'],color='#6f5ced')
ax3.plot(pc['PDF_He.1'],color='#e85a5a')
ax3.plot(pc['IR_He'],color='#9587ed')
ax3.plot(pc['IR_He.1'],color='#e08080')


import matplotlib.patches as mpatches
colors1 = ["#cce5cc", '#f5a169']
texts1 = ["Transition I", "Transition II"]
colors2 = ['#ed2f2f', '#e85a5a', '#e08080']
texts2 = [r'XRD (End Corr.)',r'PDF (End Corr.)',r'IR (End Corr.)']
colors3 = ['#4c34eb','#6f5ced','#9587ed']
texts3 = [r'XRD (Start Corr.)',r'PDF (Start Corr.)',r'IR (Start Corr.)']

patches1 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors1[i], 
            label="{:s}".format(texts1[i]) )[0]  for i in range(len(texts1))]
patches2 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors2[i], 
            label="{:s}".format(texts2[i]) )[0]  for i in range(len(texts2)) ]
patches3 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors3[i], 
            label="{:s}".format(texts3[i]) )[0]  for i in range(len(texts3))]

first_legend = ax0.legend(handles=patches1,loc='upper left', ncol=1, facecolor=None, frameon=False,fontsize=6)
second_legend = ax0.legend(handles=patches3,loc='lower right', ncol=1, facecolor=None, frameon=False,fontsize=6)
third_legend = ax3.legend(handles=patches1,loc='upper left', ncol=1, facecolor=None, frameon=False,fontsize=6)
fourth_legend = ax3.legend(handles=patches3,loc='lower right', ncol=1, facecolor=None, frameon=False,fontsize=6)

ax0.add_artist(first_legend)
ax0.add_artist(second_legend)
ax3.add_artist(third_legend)
ax3.add_artist(fourth_legend)

ax0.legend(handles=patches2,loc='upper right', ncol=1, facecolor=None, frameon=False,fontsize=6)
ax3.legend(handles=patches2,loc='upper right', ncol=1, facecolor=None, frameon=False,fontsize=6)

x_axis = (np.array(pc.index))
ax0.fill_between(x_axis[7:21],pc.iloc[7:21,2],pc.iloc[7:21,8],facecolor='green', alpha=0.2, interpolate=True)
ax0.fill_between(x_axis[30:38],pc.iloc[30:38,2],pc.iloc[30:38,8],facecolor='#f5a169', alpha=0.8, interpolate=True)
ax0.fill_between(x_axis[37:44],pc.iloc[37:44,0],pc.iloc[37:44,6],facecolor='#f5a169', alpha=0.8, interpolate=True)
ax3.fill_between(x_axis[7:21],pc.iloc[7:21,3],pc.iloc[7:21,9],facecolor='green', alpha=0.2, interpolate=True)
ax3.fill_between(x_axis[72:],pc.iloc[72:,3],pc.iloc[72:,9],facecolor='#f5a169', alpha=0.8, interpolate=True)

ax0.set_title(r'Red. Flow $(H_{2})$',loc='left', pad=4, fontsize=8)
ax3.set_title(r'Inert Flow $(He)$',loc='left', pad=4, fontsize=8)

plt.savefig('20210402_Dan_AgA_DifferentialPearsonPlots.tif',bbox_inches='tight',dpi=600)

# %%
import matplotlib.gridspec as gridspec
import pandas as pd

pc = pd.read_csv('DifferentialPearson.csv',sep=',',index_col=0,header=1,skiprows=[2])

f = plt.figure(dpi=600, edgecolor=None)
f.set_figheight(3.33*1)
f.set_figwidth(3.33*2)
gs0 = gridspec.GridSpec(1, 1, figure=f, hspace=0,wspace=0)
G00 = gridspec.GridSpecFromSubplotSpec(nrows=1, ncols=2, subplot_spec=gs0[0], hspace=0.2, wspace=0.2)
plt.rcParams.update({'font.size': 8})

ax0 = plt.subplot(G00[0,0])
ax0.set_ylabel(r'$\Delta$(Pearson Corr.)')
ax0.set_xlabel(r'Temp. / $^\circ$C')
ax0.set_ylim(-0.052,0.025)

ax0.plot(pc['XRD_H2'],color='#00026e')
ax0.plot(pc['XRD_H2.1']*(-1),color='#a80000')
ax0.plot(pc['PDF_H2'],color='#3d3fd1')
ax0.plot(pc['PDF_H2.1']*(-1),color='#ed4747')
ax0.plot(pc['IR_H2'],color='#85bced')
ax0.plot(pc['IR_H2.1']*(-1),color='#ffb8b8')

ax3 = plt.subplot(G00[0,1])
ax3.set_xlabel(r'Temp. / $^\circ$C')
ax3.set_ylim(-0.032,0.017)

ax3.plot(pc['XRD_He'],color='#00026e')
ax3.plot(pc['XRD_He.1']*(-1),color='#a80000')
ax3.plot(pc['PDF_He'],color='#3d3fd1')
ax3.plot(pc['PDF_He.1']*(-1),color='#ed4747')
ax3.plot(pc['IR_He'],color='#85bced')
ax3.plot(pc['IR_He.1']*(-1),color='#ffb8b8')


import matplotlib.patches as mpatches
colors1 = ["#cce5cc", '#f5a169']
texts1 = ["Transition I", "Transition II"]
colors2 = ['#a80000', '#ed4747', '#ffb8b8']
texts2 = [r'XRD (End Corr.)',r'PDF (End Corr.)',r'IR (End Corr.)']
colors3 = ['#00026e','#3d3fd1','#85bced']
texts3 = [r'XRD (Start Corr.)',r'PDF (Start Corr.)',r'IR (Start Corr.)']

patches1 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors1[i], 
            label="{:s}".format(texts1[i]) )[0]  for i in range(len(texts1))]
patches2 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors2[i], 
            label="{:s}".format(texts2[i]) )[0]  for i in range(len(texts2)) ]
patches3 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors3[i], 
            label="{:s}".format(texts3[i]) )[0]  for i in range(len(texts3))]

first_legend = ax0.legend(handles=patches1,loc='upper left', ncol=1, facecolor=None, frameon=False,fontsize=6)
second_legend = ax0.legend(handles=patches3,loc='lower right', ncol=1, facecolor=None, frameon=False,fontsize=6)
third_legend = ax3.legend(handles=patches1,loc='upper left', ncol=1, facecolor=None, frameon=False,fontsize=6)
fourth_legend = ax3.legend(handles=patches3,loc='lower right', ncol=1, facecolor=None, frameon=False,fontsize=6)

ax0.add_artist(first_legend)
ax0.add_artist(second_legend)
ax3.add_artist(third_legend)
ax3.add_artist(fourth_legend)

ax0.legend(handles=patches2,loc='upper right', ncol=1, facecolor=None, frameon=False,fontsize=6)
ax3.legend(handles=patches2,loc='upper right', ncol=1, facecolor=None, frameon=False,fontsize=6)

import numpy as np
x_axis = (np.array(pc.index))
x_axis1 = [49.8,53.1,56.4,59.7,63.0,66.3,69.5,72.8,76.1,79.4,82.7,89.2,92.5,95.8]
x_axis2 = [128.6,131.9,135.2,138.4,141.7,145.0,148.3,154.8,158.1,161.4,164.7,168.0,171.3,174.5]
x_axis3 = [273.0,276.3,279.5,286.1,289.4,292.7,295.9,299.2,302.5,305.8,309.1,312.3,315.6,318.9]

ax0.barh(0.005,width=x_axis1[-1]-x_axis1[0],height=0.0025,left=x_axis1[0], color="#cce5cc")
ax0.barh(0.005,width=x_axis2[-1]-x_axis2[0],height=0.0025,left=x_axis2[0], color='#f5a169')
ax3.barh(0.004,width=x_axis1[-1]-x_axis1[0],height=0.0015,left=x_axis1[0], color="#cce5cc")
ax3.barh(0.004,width=x_axis3[-1]-x_axis3[0],height=0.0015,left=x_axis3[0], color='#f5a169')

ax0.set_title(r'Red. Flow $(H_{2})$',loc='left', pad=4, fontsize=8)
ax3.set_title(r'Inert Flow $(He)$',loc='left', pad=4, fontsize=8)

plt.savefig('20210402_Dan_AgA_DifferentialPearsonPlots_alt.tif',bbox_inches='tight',dpi=600)

# %%
pearson_output = pd.concat([XRD_H2_Pearson.iloc[:,25],XRD_He_Pearson.iloc[:,25],
                            PDF_H2_Pearson.iloc[:,25],PDF_He_Pearson.iloc[:,25], 
                            IR_H2_Pearson.iloc[:,25],IR_He_Pearson.iloc[:,25]],join='outer', axis=1)
pearson_output.to_csv('pearson_output25.csv',sep=',')

# %%
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os, glob


pc = pd.read_csv(
    r'C:\Crystallography\_3_analysis\2020_AgA_H2_NMF\20200930_Dan_AgA\DifferentialPearson.csv',
    sep=',',index_col=0,header=1,skiprows=[2]
)

f = plt.figure(dpi=600, edgecolor=None)
f.patch.set_facecolor('w')
f.set_figheight(3.33*1)
f.set_figwidth(3.33*2)
gs0 = gridspec.GridSpec(1, 1, figure=f, hspace=0,wspace=0)
G00 = gridspec.GridSpecFromSubplotSpec(nrows=1, ncols=2, subplot_spec=gs0[0], hspace=0.2, wspace=0.2)
plt.rcParams.update({'font.size': 8})

ax0 = plt.subplot(G00[0,0])
ax0.set_ylabel(r'$\Delta$(Pearson Corr.)')
ax0.set_xlabel(r'Temp. / $^\circ$C')
ax0.set_ylim(-0.008,0.055)

ax0.plot(abs(pc['XRD_H2']),color='#00026e', linewidth=1)
ax0.plot(abs(pc['XRD_H2.1']),color='#a80000', linewidth=1)
ax0.plot(abs(pc['PDF_H2']),color='#3d3fd1', linewidth=1)
ax0.plot(abs(pc['PDF_H2.1']),color='#ed4747', linewidth=1)
ax0.plot(abs(pc['IR_H2']),color='#85bced', linewidth=1)
ax0.plot(abs(pc['IR_H2.1']),color='#ffb8b8', linewidth=1)

ax1 = plt.subplot(G00[0,1])
ax1.set_xlabel(r'Temp. / $^\circ$C')
ax1.set_ylim(-0.004,0.036)

ax1.plot(abs(pc['XRD_He']),color='#00026e', linewidth=1)
ax1.plot(abs(pc['XRD_He.1']),color='#a80000', linewidth=1)
ax1.plot(abs(pc['PDF_He']),color='#3d3fd1', linewidth=1)
ax1.plot(abs(pc['PDF_He.1']),color='#ed4747', linewidth=1)
ax1.plot(abs(pc['IR_He']),color='#85bced', linewidth=0.75)
ax1.plot(abs(pc['IR_He.1']),color='#ffb8b8', linewidth=1)


import matplotlib.patches as mpatches
colors1 = ["#cce5cc", '#f5a169']
texts1 = ["Transition I", "Transition II"]
patches1 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors1[i], 
            label="{:s}".format(texts1[i]) )[0]  for i in range(len(texts1))]
first_legend = ax0.legend(handles=patches1,loc='upper left', ncol=1, facecolor=None, frameon=False,fontsize=6)
second_legend = ax1.legend(handles=patches1,loc='upper left', ncol=1, facecolor=None, frameon=False,fontsize=6)
ax0.add_artist(first_legend)
ax1.add_artist(second_legend)

colors2 = ['#a80000', '#ed4747', '#ffb8b8','#00026e','#3d3fd1','#85bced']
texts2 = [r'XRD (End Corr.)',r'PDF (End Corr.)',r'IR (End Corr.)',r'XRD (Start Corr.)',r'PDF (Start Corr.)',r'IR (Start Corr.)']
patches2 = [plt.plot([],[], marker="s", ms=6, ls="", mec=None, color=colors2[i], 
            label="{:s}".format(texts2[i]) )[0]  for i in range(len(texts2)) ]
ax0.legend(handles=patches2,loc='upper right', ncol=1, facecolor=None, frameon=False,fontsize=6)
ax1.legend(handles=patches2,loc='upper right', ncol=1, facecolor=None, frameon=False,fontsize=6)

import numpy as np
x_axis = (np.array(pc.index))
x_axis1 = [49.8,53.1,56.4,59.7,63.0,66.3,69.5,72.8,76.1,79.4,82.7,89.2,92.5,95.8]
x_axis2 = [128.6,131.9,135.2,138.4,141.7,145.0,148.3,154.8,158.1,161.4,164.7,168.0,171.3,174.5]
x_axis3 = [273.0,276.3,279.5,286.1,289.4,292.7,295.9,299.2,302.5,305.8,309.1,312.3,315.6,318.9]

h1 = ((0.055-(-0.008))*0.05)-0.008 #0.005
h2 = ((0.036-(-0.004))*0.05)-0.004 #0.0022

ax0.barh(h1,width=x_axis1[-1]-x_axis1[0],height=0.0025,left=x_axis1[0], color="#cce5cc")
ax0.barh(h1,width=x_axis2[-1]-x_axis2[0],height=0.0025,left=x_axis2[0], color='#f5a169')
ax1.barh(h2,width=x_axis1[-1]-x_axis1[0],height=0.0015,left=x_axis1[0], color="#cce5cc")
ax1.barh(h2,width=x_axis3[-1]-x_axis3[0],height=0.0015,left=x_axis3[0], color='#f5a169')

ax0.set_title(r'Red. Flow $(H_{2})$',loc='left', pad=4, fontsize=8)
ax1.set_title(r'Inert Flow $(He)$',loc='left', pad=4, fontsize=8)

plt.savefig('202104027_Dan_AgA_DifferentialPearsonPlots_test.svg',format='svg',bbox_inches='tight',dpi=600,facecolor=f.get_facecolor(), edgecolor='none')
